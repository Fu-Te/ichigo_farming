# %%
import datetime as dt
import json
import hashlib
import pandas as pd


class MyBlockChain(object):
    # ブロックチェーンを初期化する
    def __init__(self):
        self.chain = []

    # 新しいブロックを作成する
    def add_new_block(self, inp, outp):
        # トランザクションを生成する
        new_transaction = self.__create_new_transaction(inp, outp)
       
        # 前のブロックのハッシュを取得。最初だけ固定値
        if len(self.chain) > 0:
            prev_hash = self.chain[-1]['block_header']['tran_hash']
        else:
            prev_hash = "747bc42088cf0b3915982af289189e8f14d3325a7d594bc2d30a7014a536cb13"

        # トランザクションを元にブロックを生成して、チェーンに接続する
        new_block = {
            'block_index': len(self.chain) + 1,
            'block_time': dt.datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
            'block_header': {
                'prev_hash': prev_hash,
                'tran_hash': self.__hash(prev_hash + self.__calc_tran_hash(new_transaction)),
            },
            'tran_counter': len(inp) + len(outp),
            'tran_body': new_transaction,
        }
        self.chain.append(new_block)
        return new_block

    # 新しいトランザクションを生成する
    def __create_new_transaction(self, inp, outp):
        new_transaction = {
            'input': inp,
            'output': outp,
        }
        return new_transaction

    # ハッシュ値を計算する。SortをTrueにしているのはハッシュの整合性維持のため
    def __calc_tran_hash(self, new_transaction):
        tran_string = json.dumps(new_transaction, sort_keys=True).encode()
        return self.__hash(tran_string)
    
    def __hash(self, str_seed):
        return hashlib.sha256(str(str_seed).encode()).hexdigest()

    # ブロックの内容を表示する
    def dump(self, block_index=0):
        if(block_index == 0):
            print(json.dumps(self.chain, sort_keys=False, indent=2))
        else:
            print(
                json.dumps(
                    self.chain[block_index],
                    sort_keys=False,
                    indent=2))

# %%
df1 = pd.read_csv("sample1.csv")
df2 = pd.read_csv('sample2.csv')
df3 = pd.read_csv('sample3.csv')
df4 = pd.read_csv('sample4.csv')

df = pd.concat([df1,df2])
df = pd.concat([df,df3])
df = pd.concat([df,df4])


        
bc = MyBlockChain()

# %%
df_count = df['MAC'].value_counts().to_frame()
df_count=df_count.reset_index()

df['count'] = df_count['MAC']

# %%
df.head()
# Out:
#        Gakuseki                MAC  count
# 0   19G0001005D  73:57:EE:08:6F:85      4
# 1   19G0002002K  2E:FA:10:17:35:8A      4
# 2   19G0811006G  6E:A5:55:4A:C5:CC      4
# 3  19G11114008U  43:10:65:8D:0E:78      4
# 4   19G1111007E  1A:3E:E3:5F:87:79      4

# %%
for gakuseki, mac, count in zip(df['Gakuseki'],df['MAC'],df['count']):
    if count >= 3: #もう少しかっこよく50%以上を表現できると良い
        inp = {
        'GAC': gakuseki,
        }
        out = {
        'MAC': mac,
        }
        bc.add_new_block(inp, out)


bc.dump()
# Out:
# [
#   {
#     "block_index": 1,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "747bc42088cf0b3915982af289189e8f14d3325a7d594bc2d30a7014a536cb13",
#       "tran_hash": "5fefbc8128db658dc362b22fcfee2cfae1a1c2533a6c4391486f70d4c931c07f"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0001005D"
#       },
#       "output": {
#         "MAC": "73:57:EE:08:6F:85"
#       }
#     }
#   },
#   {
#     "block_index": 2,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "5fefbc8128db658dc362b22fcfee2cfae1a1c2533a6c4391486f70d4c931c07f",
#       "tran_hash": "a24ce7e4f4058b7cd4bfe92c129bf7031615d9ea1395b6bb1f914acf77bd60b4"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0002002K"
#       },
#       "output": {
#         "MAC": "2E:FA:10:17:35:8A"
#       }
#     }
#   },
#   {
#     "block_index": 3,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "a24ce7e4f4058b7cd4bfe92c129bf7031615d9ea1395b6bb1f914acf77bd60b4",
#       "tran_hash": "471f9620d1c1690fd341b5c048e78920de05b8277005163259ff6092fd0dbbc3"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0811006G"
#       },
#       "output": {
#         "MAC": "6E:A5:55:4A:C5:CC"
#       }
#     }
#   },
#   {
#     "block_index": 4,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "471f9620d1c1690fd341b5c048e78920de05b8277005163259ff6092fd0dbbc3",
#       "tran_hash": "f5460ddb9bb9a330d3f2b52097beeb7ee786ba9166563d1c8b3a6d71191e730e"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G11114008U"
#       },
#       "output": {
#         "MAC": "43:10:65:8D:0E:78"
#       }
#     }
#   },
#   {
#     "block_index": 5,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "f5460ddb9bb9a330d3f2b52097beeb7ee786ba9166563d1c8b3a6d71191e730e",
#       "tran_hash": "f674a920644dba7fd0915d573e404512521c8029974b9c0fb1a5dfd86309ad86"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G1111007E"
#       },
#       "output": {
#         "MAC": "1A:3E:E3:5F:87:79"
#       }
#     }
#   },
#   {
#     "block_index": 6,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "f674a920644dba7fd0915d573e404512521c8029974b9c0fb1a5dfd86309ad86",
#       "tran_hash": "223a4c1df787413abf9aa6bdb56c64d60ca586db700adabf1dd616fe986d3f4c"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0001005D"
#       },
#       "output": {
#         "MAC": "73:57:EE:08:6F:85"
#       }
#     }
#   },
#   {
#     "block_index": 7,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "223a4c1df787413abf9aa6bdb56c64d60ca586db700adabf1dd616fe986d3f4c",
#       "tran_hash": "2987e91c8aa2b08c3c470996e63d82b9f7a5e4108ee9a1f2a89855e7cd0ac583"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0002002K"
#       },
#       "output": {
#         "MAC": "2E:FA:10:17:35:8A"
#       }
#     }
#   },
#   {
#     "block_index": 8,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "2987e91c8aa2b08c3c470996e63d82b9f7a5e4108ee9a1f2a89855e7cd0ac583",
#       "tran_hash": "835111a461c4f915a8967b17359d097be30437e4969516b4e2ceeebbd35e154f"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0811006G"
#       },
#       "output": {
#         "MAC": "6E:A5:55:4A:C5:CC"
#       }
#     }
#   },
#   {
#     "block_index": 9,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "835111a461c4f915a8967b17359d097be30437e4969516b4e2ceeebbd35e154f",
#       "tran_hash": "2e7bd58904a224605cf27ea89c6b2cf79092a30a732a19341ad3fa9c0a725abf"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G11114008U"
#       },
#       "output": {
#         "MAC": "43:10:65:8D:0E:78"
#       }
#     }
#   },
#   {
#     "block_index": 10,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "2e7bd58904a224605cf27ea89c6b2cf79092a30a732a19341ad3fa9c0a725abf",
#       "tran_hash": "d61a36c298e8baf403ba30a0e54a6c206e2f2437841db9ba1e19783b2ac4889a"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G1111007E"
#       },
#       "output": {
#         "MAC": "1A:3E:E3:5F:87:79"
#       }
#     }
#   },
#   {
#     "block_index": 11,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "d61a36c298e8baf403ba30a0e54a6c206e2f2437841db9ba1e19783b2ac4889a",
#       "tran_hash": "30be3d2ab0e80be114fcd32479b743a5b3b295f788be14db977ecb8d8b7983ef"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0001005D"
#       },
#       "output": {
#         "MAC": "73:57:EE:08:6F:85"
#       }
#     }
#   },
#   {
#     "block_index": 12,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "30be3d2ab0e80be114fcd32479b743a5b3b295f788be14db977ecb8d8b7983ef",
#       "tran_hash": "6e64f074077738c87d8ae27f2a9b9f7841fb57bc4c5d945ca0535e8d36dcf17f"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0002002K"
#       },
#       "output": {
#         "MAC": "2E:FA:10:17:35:8A"
#       }
#     }
#   },
#   {
#     "block_index": 13,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "6e64f074077738c87d8ae27f2a9b9f7841fb57bc4c5d945ca0535e8d36dcf17f",
#       "tran_hash": "13d35ba0a1b674af235df19b22891ac8d52f7a3be585d5fca3a27168362b777b"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0811006G"
#       },
#       "output": {
#         "MAC": "6E:A5:55:4A:C5:CC"
#       }
#     }
#   },
#   {
#     "block_index": 14,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "13d35ba0a1b674af235df19b22891ac8d52f7a3be585d5fca3a27168362b777b",
#       "tran_hash": "2d5e4b80406308c794becc4238663464624ef903ba80a7ace4a3d0e49a4d2554"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G11114008U"
#       },
#       "output": {
#         "MAC": "43:10:65:8D:0E:78"
#       }
#     }
#   },
#   {
#     "block_index": 15,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "2d5e4b80406308c794becc4238663464624ef903ba80a7ace4a3d0e49a4d2554",
#       "tran_hash": "c8da6952e3bf045e8050608d69c6315f25b5454edf39758aa3a1e5e206f2c4f5"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G1111007E"
#       },
#       "output": {
#         "MAC": "1A:3E:E3:5F:87:79"
#       }
#     }
#   },
#   {
#     "block_index": 16,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "c8da6952e3bf045e8050608d69c6315f25b5454edf39758aa3a1e5e206f2c4f5",
#       "tran_hash": "d041f8e939c1a6f8eeb38e79969aa20a5046583953068a396edee12ae052f9dc"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0001005D"
#       },
#       "output": {
#         "MAC": "73:57:EE:08:6F:85"
#       }
#     }
#   },
#   {
#     "block_index": 17,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "d041f8e939c1a6f8eeb38e79969aa20a5046583953068a396edee12ae052f9dc",
#       "tran_hash": "cc50552e36e9b9de296910df41411f79ff4f0911ea5515a8632778ebcbea9e8d"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0002002K"
#       },
#       "output": {
#         "MAC": "2E:FA:10:17:35:8A"
#       }
#     }
#   },
#   {
#     "block_index": 18,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "cc50552e36e9b9de296910df41411f79ff4f0911ea5515a8632778ebcbea9e8d",
#       "tran_hash": "5c805d6358a1d9ef7344c12eccac9baed78226359def670ef099c6eafa88a23e"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G0811006G"
#       },
#       "output": {
#         "MAC": "6E:A5:55:4A:C5:CC"
#       }
#     }
#   },
#   {
#     "block_index": 19,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "5c805d6358a1d9ef7344c12eccac9baed78226359def670ef099c6eafa88a23e",
#       "tran_hash": "b5b29f1b3a95b1327492e0bcf9a5e87bfa55b97ed37616b0bcb271d1f21c5fc9"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G11114008U"
#       },
#       "output": {
#         "MAC": "43:10:65:8D:0E:78"
#       }
#     }
#   },
#   {
#     "block_index": 20,
#     "block_time": "2022-07-14 09:25:11",
#     "block_header": {
#       "prev_hash": "b5b29f1b3a95b1327492e0bcf9a5e87bfa55b97ed37616b0bcb271d1f21c5fc9",
#       "tran_hash": "e53c2a47e310a93221399b20746df3293fb8982784254673dda0bdba1e64110c"
#     },
#     "tran_counter": 2,
#     "tran_body": {
#       "input": {
#         "GAC": "19G1111007E"
#       },
#       "output": {
#         "MAC": "1A:3E:E3:5F:87:79"
#       }
#     }
#   }
# ]
